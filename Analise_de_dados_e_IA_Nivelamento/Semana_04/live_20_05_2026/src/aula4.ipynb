# %%
professores = ['Danilo','Toninho','Alvani','Aldaiza','Leninha','Sônia']
disciplinas = ['Python','História','Matemática','Química','Biologia','Português']

# print(len(professores))
# print(len(disciplinas))
# print("Os professores são:")
# for nome in professores:
#     print(nome)
# print("\n")
# print("As matérias são:")
# for materias in disciplinas:
#     print(materias)

for i in range(len(professores)):
    print(f"O/a professor/a {professores[i]} ensina {disciplinas[i]}")
# Out:
# O/a professor/a Danilo ensina Python
# O/a professor/a Toninho ensina História
# O/a professor/a Alvani ensina Matemática
# O/a professor/a Aldaiza ensina Química
# O/a professor/a Leninha ensina Biologia
# O/a professor/a Sônia ensina Português

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in C:\Users\Thierry-G15\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\Thierry-G15\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Thierry-G15\AppData\Roaming\Python\Python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\Thierry-G15\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\Thierry-G15\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in C:\Users\Thierry-G15\AppData\Roaming\Python\Python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
professores = ['Danilo','Toninho','Alvani','Aldaiza','Leninha','Sônia']
disciplinas = ['Python','História','Matemática','Química','Biologia','Português']
dados = {
    'profs': professores,
    'materias':disciplinas
}
print(pd.DataFrame(dados))
# Out:
#      profs    materias
# 0   Danilo      Python
# 1  Toninho    História
# 2   Alvani  Matemática
# 3  Aldaiza     Química
# 4  Leninha    Biologia
# 5    Sônia   Português

# %%
carros = {
    'modelo':['uno','gol','polo','kombi'],
    'preço':[20000,30000,60000,15000],
    'marca':['fiat','vw','vw','vw'],
    'fabricação':[2005,2015,2023,1975]

}
carros = pd.DataFrame(carros)
carros.to_excel('carros.xlsx')
