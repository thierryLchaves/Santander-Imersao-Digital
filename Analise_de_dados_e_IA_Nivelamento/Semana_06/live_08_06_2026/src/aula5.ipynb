# %%
# !pip install pandas
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pandas in c:\users\tlchaves\appdata\local\programs\python\python312\lib\site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\tlchaves\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tlchaves\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tlchaves\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tlchaves\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\tlchaves\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\tlchaves\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\tlchaves\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\tlchaves\AppData\Local\Programs\Python\Python312\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pip in c:\users\tlchaves\appdata\local\programs\python\python312\lib\site-packages (25.1.1)
# Collecting pip
#   Using cached pip-26.1.2-py3-none-any.whl.metadata (4.6 kB)
# Using cached pip-26.1.2-py3-none-any.whl (1.8 MB)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\tlchaves\AppData\Local\Programs\Python\Python312\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: To modify pip, please run the following command:
# C:\Users\tlchaves\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
dados = pd.read_excel("carros.xlsx")
dados.head()
# Out:
#    Unnamed: 0       marca   modelo   ano   preco  potencia_cv combustivel  \
# 0           0  Volkswagen     Polo  2021   72000          116        flex
# 1           1        Fiat     Argo  2020   61000          109        flex
# 2           2   Chevrolet     Onix  2022   78000          116        flex
# 3           3      Toyota  Corolla  2019  115000          154    gasolina
# 4           4       Honda    Civic  2020  110000          150    gasolina
#
#        cambio  quilometragem categoria     cor  numero_donos  \
# 0  automático          42000     hatch   prata             1
# 1      manual          55000     hatch  branco             2
# 2  automático          18000     hatch   preto             1
# 3  automático          68000     sedan   cinza             2
# 4  automático          50000     sedan   preto             2
#
#   estado_conservacao  vendido    cidade_venda
# 0                bom     True       São Paulo
# 1            regular     True  Rio de Janeiro
# 2              ótimo     True  Belo Horizonte
# 3                bom    False        Curitiba
# 4                bom     True       São Paulo

# %%
dados[['modelo','ano','combustivel']]
# Out:
#       modelo   ano combustivel
# 0       Polo  2021        flex
# 1       Argo  2020        flex
# 2       Onix  2022        flex
# 3    Corolla  2019    gasolina
# 4      Civic  2020    gasolina
# 5       HB20  2021        flex
# 6   Renegade  2022        flex
# 7       Kwid  2020        flex
# 8   EcoSport  2018        flex
# 9      Kicks  2021        flex
# 10   T-Cross  2023        flex
# 11    Cronos  2022        flex
# 12   Tracker  2023        flex
# 13     Hilux  2021      diesel
# 14      City  2022        flex
# 15     Creta  2023        flex
# 16   Compass  2021      diesel
# 17    Duster  2020        flex
# 18    Ranger  2019      diesel
# 19     Versa  2022        flex

# %%
for i in range(len(dados['quilometragem'])):
    if dados['quilometragem'][i] < 50000:
        print(dados['modelo'][i],dados['ano'][i], dados['quilometragem'][i])
# Out:
# Polo 2021 42000
# Onix 2022 18000
# HB20 2021 39000
# Renegade 2022 15000
# Kicks 2021 30000
# T-Cross 2023 8000
# Cronos 2022 22000
# Tracker 2023 12000
# Hilux 2021 45000
# City 2022 20000
# Creta 2023 10000
# Versa 2022 25000

# %%
dados_filtragem = dados[dados['quilometragem']<50000]
dados_filtragem[['modelo','ano','quilometragem']]
dados_filtragem.to_excel("Carros_filtrados.xlsx")

# %%
dados['marca'].value_counts()
# Out:
# marca
# Volkswagen    2
# Fiat          2
# Chevrolet     2
# Toyota        2
# Honda         2
# Hyundai       2
# Jeep          2
# Renault       2
# Ford          2
# Nissan        2
# Name: count, dtype: int64

# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-6.8.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Downloading narwhals-2.22.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging in c:\users\tlchaves\appdata\local\programs\python\python312\lib\site-packages (from plotly) (25.0)
# Downloading plotly-6.8.0-py3-none-any.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ------- -------------------------------- 1.8/9.9 MB 12.6 MB/s eta 0:00:01
#    --------------- ------------------------ 3.9/9.9 MB 11.2 MB/s eta 0:00:01
#    -------------------------- ------------- 6.6/9.9 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.7/9.9 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 11.0 MB/s eta 0:00:00
# Downloading narwhals-2.22.1-py3-none-any.whl (454 kB)
# Installing collected packages: narwhals, plotly
#
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    ---------------------------------------- 2/2 [plotly]
#
# Successfully installed narwhals-2.22.1 plotly-6.8.0
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\tlchaves\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\tlchaves\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\tlchaves\AppData\Local\Programs\Python\Python312\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
dados['categoria'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
import matplotlib.pyplot as plt
dados['categoria'].value_counts().plot.pie()
plt.savefig("grafico.png")
plt.show()

# %%
dados.groupby('cambio')['quilometragem'].mean()
# Out:
# cambio
# automático    36000.0
# manual        54000.0
# Name: quilometragem, dtype: float64

# %%
dados[dados['quilometragem'] > dados['quilometragem'].mean()]
# Out:
#     Unnamed: 0       marca    modelo   ano   preco  potencia_cv combustivel  \
# 0            0  Volkswagen      Polo  2021   72000          116        flex
# 1            1        Fiat      Argo  2020   61000          109        flex
# 3            3      Toyota   Corolla  2019  115000          154    gasolina
# 4            4       Honda     Civic  2020  110000          150    gasolina
# 7            7     Renault      Kwid  2020   48000           70        flex
# 8            8        Ford  EcoSport  2018   67000          137        flex
# 13          13      Toyota     Hilux  2021  245000          204      diesel
# 16          16        Jeep   Compass  2021  175000          185      diesel
# 17          17     Renault    Duster  2020   89000          120        flex
# 18          18        Ford    Ranger  2019  210000          200      diesel
#
#         cambio  quilometragem categoria       cor  numero_donos  \
# 0   automático          42000     hatch     prata             1
# 1       manual          55000     hatch    branco             2
# 3   automático          68000     sedan     cinza             2
# 4   automático          50000     sedan     preto             2
# 7       manual          62000     hatch    branco             2
# 8   automático          85000       SUV     prata             3
# 13  automático          45000    picape     preto             2
# 16  automático          52000       SUV    branco             2
# 17      manual          60000       SUV  vermelho             2
# 18  automático          74000    picape     prata             3
#
#    estado_conservacao  vendido    cidade_venda
# 0                 bom     True       São Paulo
# 1             regular     True  Rio de Janeiro
# 3                 bom    False        Curitiba
# 4                 bom     True       São Paulo
# 7             regular     True        Salvador
# 8             regular     True    Porto Alegre
# 13                bom    False         Goiânia
# 16                bom     True        Brasília
# 17            regular     True        Salvador
# 18                bom    False    Porto Alegre

# %%
dados.groupby('cambio')['quilometragem'].mean().plot.bar()
plt.savefig("Cambio_quilometragem.png")
plt.show()
